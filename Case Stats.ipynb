# %%
import pandas as pd, numpy as np
#from shapely.geometry import Polygon
#from shapely.geometry import Point
#import geopandas
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
path = 'Output/' # select folder with data in it

stop_stats = pd.read_csv(path + 'stop_stats.csv', delimiter=',')

cases = ['Bay Area Rapid TransitWOAK','Bay Area Rapid TransitFTVL','Bay Area Rapid TransitCOLS',
         'Metro - Los Angeles80128','Metro - Los Angeles80405','Metro - Los Angeles80209',
         'Metro - Los Angeles80205','Metro - Los Angeles80120',
         'Bay Area Rapid TransitROCK','Bay Area Rapid TransitASHB','Bay Area Rapid TransitCOLM',
         'Caltrain70162','VTA4786',
         'Caltrain70222','San Francisco Municipal Transportation Agency4787',
         'Metro - Los Angeles7297','Metro - Los Angeles89']

case_stats = stop_stats[stop_stats['key'].isin(cases)]

case_stats.to_csv(path + 'case_stats.csv')
print(len(case_stats))
case_stats.head(2)
# Out:
# 17
#       Unnamed: 0                         key  total_pop  rent_comp      jobs  \
# 1083        1083  Bay Area Rapid TransitASHB     6205.0   0.895601  993272.0
# 1088        1088  Bay Area Rapid TransitCOLM     8765.0   0.771038  860046.0
#
#       pct_rent  pct_white  pct_hispanic  pct_black  pct_asian      ...       \
# 1083  0.684013   0.459146      0.150685   0.248670   0.086865      ...
# 1088  0.745690   0.086366      0.402624   0.029435   0.470850      ...
#
#       pct_smallmf  pct_bigmf  pct_medmf  pct_vacant  pct_since2000  \
# 1083     0.325403   0.006907   0.257866    0.078281       0.019570
# 1088     0.283844   0.228123   0.162678    0.045625       0.143231
#
#       pct_before1950  pct_bach_degree  pct_hh_kids  pct_unemp_civ  \
# 1083        0.625863         0.543959     0.290591       0.071900
# 1088        0.116305         0.273219     0.470611       0.117368
#
#            density
# 1083  17728.571732
# 1088  20336.427183
#
# [2 rows x 26 columns]
